# %%
import cv2 as cv
import os
import matplotlib.pyplot as plt
import numpy as np
import keras

from keras.datasets import mnist
from keras.models import Model
from keras.layers import Input, add
from keras.layers.core import Dense, Dropout, Activation, Flatten, Reshape
from keras import regularizers
from keras.regularizers import l2
from keras.layers.convolutional import Conv2D, MaxPooling2D, UpSampling2D, ZeroPadding2D
from keras.utils import np_utils

# %%
# Load the data
data = []
label = []
IMG_SIZE = 32
prefix_path = "./Train/"
sub_paths = [str(i) for i in range(43)]
for sub_path in sub_paths:
    path = prefix_path + sub_path + "/"
    number = 0
    for file in os.listdir(path):
        img = cv.imread(path + file)
        img = cv.resize(img, (IMG_SIZE, IMG_SIZE))
        img = img.astype('float32')
        label.append(int(sub_path))
        data.append(img)
        number += 1
        if number > 200: break
data = np.array(data)

data_label = np.array([int(i) for i in label])

# %%
# Normalize the data
data = data / 255.0

# now my data is reshaped_data, and the label is data_label
# i want to split the data into train and test, ratio is 0.2
# split the data into train and test
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data, data_label, test_size=0.2, random_state=42)

# print the first picture of X_train
plt.imshow(X_train[0])
plt.show()
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')

# Flatten the images for the Fully-Connected Networks
X_train = X_train.reshape((len(X_train), np.prod(X_train.shape[1:])))
X_test = X_test.reshape((len(X_test), np.prod(X_test.shape[1:])))
# Out:
# 6914 train samples
# 1729 test samples

# %%
# Create the network
input_size = 3072
hidden_size = 64
output_size = 3072

x = Input(shape=(input_size,))
h = Dense(hidden_size, activation='relu', activity_regularizer=regularizers.l1(10e-5))(x)
r = Dense(output_size, activation='sigmoid')(h)

autoencoder = Model(inputs=x, outputs=r)
autoencoder.compile(optimizer='adam', loss='mse')

# print the structure of the model
print(autoencoder.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 3072)]            0
#
#  dense (Dense)               (None, 64)                196672
#
#  dense_1 (Dense)             (None, 3072)              199680
#
# =================================================================
# Total params: 396,352
# Trainable params: 396,352
# Non-trainable params: 0
# _________________________________________________________________
# None
# 2023-01-25 01:02:17.390754: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Train the model
epochs = 50
batch_size = 128

history = autoencoder.fit(X_train, X_train, batch_size=batch_size, epochs=epochs, verbose=1,
                          validation_data=(X_test, X_test))

conv_encoder = Model(x, h)
encoded_imgs = conv_encoder.predict(X_test)

# show encoded images
n = 10
plt.figure(figsize=(20, 8))
for i in range(n):
    ax = plt.subplot(1, n, i + 1)
    plt.imshow(encoded_imgs[i].reshape(4, 16).T)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Epoch 1/50
# 55/55 [==============================] - 2s 24ms/step - loss: 0.0943 - val_loss: 0.0812
# Epoch 2/50
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0809 - val_loss: 0.0776
# Epoch 3/50
# 55/55 [==============================] - 1s 14ms/step - loss: 0.0776 - val_loss: 0.0745
# Epoch 4/50
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0745 - val_loss: 0.0711
# Epoch 5/50
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0713 - val_loss: 0.0681
# Epoch 6/50
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0686 - val_loss: 0.0657
# Epoch 7/50
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0661 - val_loss: 0.0643
# Epoch 8/50
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0643 - val_loss: 0.0621
# Epoch 9/50
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0630 - val_loss: 0.0631
# Epoch 10/50
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0617 - val_loss: 0.0598
# Epoch 11/50
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0606 - val_loss: 0.0587
# Epoch 12/50
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0593 - val_loss: 0.0579
# Epoch 13/50
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0580 - val_loss: 0.0571
# Epoch 14/50
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0571 - val_loss: 0.0557
# Epoch 15/50
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0558 - val_loss: 0.0587
# Epoch 16/50
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0551 - val_loss: 0.0544
# Epoch 17/50
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0537 - val_loss: 0.0555
# Epoch 18/50
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0529 - val_loss: 0.0514
# Epoch 19/50
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0513 - val_loss: 0.0506
# Epoch 20/50
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0502 - val_loss: 0.0509
# Epoch 21/50
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0488 - val_loss: 0.0480
# Epoch 22/50
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0474 - val_loss: 0.0501
# Epoch 23/50
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0469 - val_loss: 0.0454
# Epoch 24/50
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0442 - val_loss: 0.0439
# Epoch 25/50
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0429 - val_loss: 0.0468
# Epoch 26/50
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0427 - val_loss: 0.0465
# Epoch 27/50
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0407 - val_loss: 0.0407
# Epoch 28/50
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0392 - val_loss: 0.0401
# Epoch 29/50
# 55/55 [==============================] - 1s 15ms/step - loss: 0.0387 - val_loss: 0.0390
# Epoch 30/50
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0376 - val_loss: 0.0383
# Epoch 31/50
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0368 - val_loss: 0.0385
# Epoch 32/50
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0361 - val_loss: 0.0383
# Epoch 33/50
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0355 - val_loss: 0.0386
# Epoch 34/50
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0352 - val_loss: 0.0379
# Epoch 35/50
# 55/55 [==============================] - 1s 24ms/step - loss: 0.0347 - val_loss: 0.0353
# Epoch 36/50
# 55/55 [==============================] - 1s 25ms/step - loss: 0.0342 - val_loss: 0.0410
# Epoch 37/50
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0340 - val_loss: 0.0368
# Epoch 38/50
# 55/55 [==============================] - 1s 18ms/step - loss: 0.0336 - val_loss: 0.0344
# Epoch 39/50
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0329 - val_loss: 0.0338
# Epoch 40/50
# 55/55 [==============================] - 1s 19ms/step - loss: 0.0324 - val_loss: 0.0333
# Epoch 41/50
# 55/55 [==============================] - 1s 21ms/step - loss: 0.0325 - val_loss: 0.0330
# Epoch 42/50
# 55/55 [==============================] - 1s 22ms/step - loss: 0.0319 - val_loss: 0.0357
# Epoch 43/50
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0323 - val_loss: 0.0342
# Epoch 44/50
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0316 - val_loss: 0.0332
# Epoch 45/50
# 55/55 [==============================] - 1s 21ms/step - loss: 0.0315 - val_loss: 0.0331
# Epoch 46/50
# 55/55 [==============================] - 1s 20ms/step - loss: 0.0314 - val_loss: 0.0323
# Epoch 47/50
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0309 - val_loss: 0.0319
# Epoch 48/50
# 55/55 [==============================] - 1s 17ms/step - loss: 0.0309 - val_loss: 0.0315
# Epoch 49/50
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0307 - val_loss: 0.0316
# Epoch 50/50
# 55/55 [==============================] - 1s 16ms/step - loss: 0.0305 - val_loss: 0.0316
# 55/55 [==============================] - 0s 4ms/step

# %%
# Predict on the test set
decoded_imgs = autoencoder.predict(X_test)

# Plot
n = 10
plt.figure(figsize=(20, 6))
for i in range(n):
    # display original
    ax = plt.subplot(3, n, i + 1)
    plt.imshow(X_test[i].reshape(32, 32, 3))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(3, n, i + n + 1)
    plt.imshow(decoded_imgs[i].reshape(32, 32, 3))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

print(history.history.keys())
# Out:
# 55/55 [==============================] - 0s 5ms/step
# dict_keys(['loss', 'val_loss'])

# %%
# Plot the losses
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
all_data = np.concatenate((X_train, X_test), axis=0)
all_data_features = autoencoder.predict(all_data)
# apply kmeans to get the clusters
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=43, random_state=0).fit(all_data_features)
# This is how our centroids look like
import matplotlib.pyplot as plt
dist_cols = 10
dist_rows = 7
bottom = 0.35
plt.figure(figsize=(3 * dist_cols, 3 * dist_rows))
for i in range(43):
    plt.subplots_adjust(bottom)
    plt.subplot(dist_rows, dist_cols, i+1)
    plt.imshow(kmeans.cluster_centers_[i].reshape(32,32,3))
plt.show()
# Out:
# 271/271 [==============================] - 2s 6ms/step
